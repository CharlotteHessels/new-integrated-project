# %% [markdown]
# # Course project
#
# This notebook includes the steps to optimize the capacity and dispatch of generators in a stylized energy system. It has been prepared to serve as a tutorial for a simple PyPSA model representing the energy system in one country, city or region.
#
#
# For the (optional) project of the course [Integrated Energy Grids](https://kurser.dtu.dk/course/2024-2025/46770?menulanguage=en) you need to deliver a report including the sections described at the end of this notebook.
#
# Please, review the [PyPSA tutorial](https://martavp.github.io/integrated-energy-grids/intro-pypsa.html) before starting this project.

# %% [markdown]
# :::{note}
# If you have not yet set up Python on your computer, you can execute this tutorial in your browser via [Google Colab](https://colab.research.google.com/). Click on the rocket in the top right corner and launch "Colab". If that doesn't work download the `.ipynb` file and import it in [Google Colab](https://colab.research.google.com/).
#
# Then install `pandas` and `pypsa` by executing the following command in a Jupyter cell at the top of the notebook.
#
# ```sh
# !pip install pandas pypsa
# ```
# :::

# %%
# !pip install pypsa
# Out:
# Requirement already satisfied: pypsa in c:\users\const\anaconda\lib\site-packages (0.33.1)
# Requirement already satisfied: numpy in c:\users\const\anaconda\lib\site-packages (from pypsa) (1.26.4)
# Requirement already satisfied: scipy in c:\users\const\anaconda\lib\site-packages (from pypsa) (1.13.1)
# Requirement already satisfied: pandas>=0.24 in c:\users\const\anaconda\lib\site-packages (from pypsa) (2.2.2)
# Requirement already satisfied: xarray in c:\users\const\anaconda\lib\site-packages (from pypsa) (2025.1.2)
# Requirement already satisfied: netcdf4 in c:\users\const\anaconda\lib\site-packages (from pypsa) (1.7.2)
# Requirement already satisfied: linopy>=0.4 in c:\users\const\anaconda\lib\site-packages (from pypsa) (0.5.0)
# Requirement already satisfied: matplotlib in c:\users\const\anaconda\lib\site-packages (from pypsa) (3.9.2)
# Requirement already satisfied: geopandas>=0.9 in c:\users\const\anaconda\lib\site-packages (from pypsa) (1.0.1)
# Requirement already satisfied: networkx>=2 in c:\users\const\anaconda\lib\site-packages (from pypsa) (3.3)
# Requirement already satisfied: deprecation in c:\users\const\anaconda\lib\site-packages (from pypsa) (2.1.0)
# Requirement already satisfied: validators in c:\users\const\anaconda\lib\site-packages (from pypsa) (0.34.0)
# Requirement already satisfied: highspy in c:\users\const\anaconda\lib\site-packages (from pypsa) (1.9.0)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\const\anaconda\lib\site-packages (from geopandas>=0.9->pypsa) (0.10.0)
# Requirement already satisfied: packaging in c:\users\const\anaconda\lib\site-packages (from geopandas>=0.9->pypsa) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\const\anaconda\lib\site-packages (from geopandas>=0.9->pypsa) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\const\anaconda\lib\site-packages (from geopandas>=0.9->pypsa) (2.0.7)
# Requirement already satisfied: bottleneck in c:\users\const\anaconda\lib\site-packages (from linopy>=0.4->pypsa) (1.3.7)
# Requirement already satisfied: toolz in c:\users\const\anaconda\lib\site-packages (from linopy>=0.4->pypsa) (0.12.0)
# Requirement already satisfied: numexpr in c:\users\const\anaconda\lib\site-packages (from linopy>=0.4->pypsa) (2.8.7)
# Requirement already satisfied: dask>=0.18.0 in c:\users\const\anaconda\lib\site-packages (from linopy>=0.4->pypsa) (2024.8.2)
# Requirement already satisfied: polars in c:\users\const\anaconda\lib\site-packages (from linopy>=0.4->pypsa) (1.22.0)
# Requirement already satisfied: tqdm in c:\users\const\anaconda\lib\site-packages (from linopy>=0.4->pypsa) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\const\anaconda\lib\site-packages (from pandas>=0.24->pypsa) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\const\anaconda\lib\site-packages (from pandas>=0.24->pypsa) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\const\anaconda\lib\site-packages (from pandas>=0.24->pypsa) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\const\anaconda\lib\site-packages (from matplotlib->pypsa) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\const\anaconda\lib\site-packages (from matplotlib->pypsa) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\const\anaconda\lib\site-packages (from matplotlib->pypsa) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\const\anaconda\lib\site-packages (from matplotlib->pypsa) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\const\anaconda\lib\site-packages (from matplotlib->pypsa) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\const\anaconda\lib\site-packages (from matplotlib->pypsa) (3.1.2)
# Requirement already satisfied: cftime in c:\users\const\anaconda\lib\site-packages (from netcdf4->pypsa) (1.6.4.post1)
# Requirement already satisfied: certifi in c:\users\const\anaconda\lib\site-packages (from netcdf4->pypsa) (2025.1.31)
# Requirement already satisfied: click>=8.1 in c:\users\const\anaconda\lib\site-packages (from dask>=0.18.0->linopy>=0.4->pypsa) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\const\anaconda\lib\site-packages (from dask>=0.18.0->linopy>=0.4->pypsa) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\const\anaconda\lib\site-packages (from dask>=0.18.0->linopy>=0.4->pypsa) (2024.6.1)
# Requirement already satisfied: partd>=1.4.0 in c:\users\const\anaconda\lib\site-packages (from dask>=0.18.0->linopy>=0.4->pypsa) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\const\anaconda\lib\site-packages (from dask>=0.18.0->linopy>=0.4->pypsa) (6.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\const\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.24->pypsa) (1.16.0)
# Requirement already satisfied: colorama in c:\users\const\anaconda\lib\site-packages (from tqdm->linopy>=0.4->pypsa) (0.4.6)
# Requirement already satisfied: locket in c:\users\const\anaconda\lib\site-packages (from partd>=1.4.0->dask>=0.18.0->linopy>=0.4->pypsa) (1.0.0)

# %%
import pandas as pd
import pypsa
# Out:
# c:\Users\const\anaconda\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\Users\const\anaconda\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# c:\Users\const\anaconda\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,

# %% [markdown]
# We start by creating the network. In this example, the country is modelled as a single node, so the network includes only one bus.
#
# We select the year 2015 and set the hours in that year as snapshots.
#
# We select a country, in this case Denmark (DNK), and add one node (electricity bus) to the network.

# %%
network = pypsa.Network()
hours_in_2017 = pd.date_range('2017-01-01 00:00Z',
                              '2017-12-31 23:00Z',
                              freq='h')

network.set_snapshots(hours_in_2017.values)

network.add("Bus",
            "electricity bus")


network.add("Bus",
            "electricity bus GERMANY")

network.add("Bus",
            "electricity bus BELGIUM")

network.add("Bus",
            "heating bus", carrier = 'heat')

network.add("Bus",
            "heating bus GERMANY", carrier = 'heat')

network.add("Bus",
            "heating bus BELGIUM", carrier = 'heat')

network.snapshots
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 01:00:00',
#                '2017-01-01 02:00:00', '2017-01-01 03:00:00',
#                '2017-01-01 04:00:00', '2017-01-01 05:00:00',
#                '2017-01-01 06:00:00', '2017-01-01 07:00:00',
#                '2017-01-01 08:00:00', '2017-01-01 09:00:00',
#                ...
#                '2017-12-31 14:00:00', '2017-12-31 15:00:00',
#                '2017-12-31 16:00:00', '2017-12-31 17:00:00',
#                '2017-12-31 18:00:00', '2017-12-31 19:00:00',
#                '2017-12-31 20:00:00', '2017-12-31 21:00:00',
#                '2017-12-31 22:00:00', '2017-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='snapshot', length=8760, freq=None)

# %% [markdown]
# The demand is represented by the historical electricity demand in 2015 with hourly resolution.
#
# The file with historical hourly electricity demand for every European country is available in the data folder.
#
# The electricity demand time series were obtained from ENTSOE through the very convenient compilation carried out by the Open Power System Data (OPSD). https://data.open-power-system-data.org/time_series/

# %%
# load electricity demand data
df_elec = pd.read_csv('electricity_demand.csv', sep=';', index_col=0) # in MWh
df_elec.index = pd.to_datetime(df_elec.index) #change index to datatime
country='NLD'
country2 = 'DEU'
country3 = 'BEL'
print(df_elec[country].head())
df_heat = pd.read_csv('heat_demand.csv', sep=';', index_col=0)
# Out:
# utc_time
# 2015-01-01 00:00:00+00:00    11338.0
# 2015-01-01 01:00:00+00:00    10917.0
# 2015-01-01 02:00:00+00:00    10473.0
# 2015-01-01 03:00:00+00:00    10200.0
# 2015-01-01 04:00:00+00:00    10182.0
# Name: NLD, dtype: float64

# %%
nodes = pd.Series(['NLD','DEU','BEL']).values

# longitude
xs = {'NLD':5.291266,
     'DEU':10.451526,
     'BEL':4.469936}

# latitude
ys = {'NLD':52.132633,
     'DEU':51.165691,
     'BEL':50.503887}

network.add("Bus",'NLD',x=xs['NLD'],y=ys['NLD'])
network.add("Bus",'DEU',x=xs['DEU'],y=ys['DEU'])
network.add("Bus",'BEL',x=xs['BEL'],y=ys['BEL'])
# Out:
# Index(['BEL'], dtype='object')

# %% [markdown]
# Print the load time series to check that it has been properly added (you should see numbers and not 'NaN')

# %%
network.loads_t.p_set
# Out:
# Empty DataFrame
# Columns: []
# Index: [2017-01-01 00:00:00, 2017-01-01 01:00:00, 2017-01-01 02:00:00, 2017-01-01 03:00:00, 2017-01-01 04:00:00, 2017-01-01 05:00:00, 2017-01-01 06:00:00, 2017-01-01 07:00:00, 2017-01-01 08:00:00, 2017-01-01 09:00:00, 2017-01-01 10:00:00, 2017-01-01 11:00:00, 2017-01-01 12:00:00, 2017-01-01 13:00:00, 2017-01-01 14:00:00, 2017-01-01 15:00:00, 2017-01-01 16:00:00, 2017-01-01 17:00:00, 2017-01-01 18:00:00, 2017-01-01 19:00:00, 2017-01-01 20:00:00, 2017-01-01 21:00:00, 2017-01-01 22:00:00, 2017-01-01 23:00:00, 2017-01-02 00:00:00, 2017-01-02 01:00:00, 2017-01-02 02:00:00, 2017-01-02 03:00:00, 2017-01-02 04:00:00, 2017-01-02 05:00:00, 2017-01-02 06:00:00, 2017-01-02 07:00:00, 2017-01-02 08:00:00, 2017-01-02 09:00:00, 2017-01-02 10:00:00, 2017-01-02 11:00:00, 2017-01-02 12:00:00, 2017-01-02 13:00:00, 2017-01-02 14:00:00, 2017-01-02 15:00:00, 2017-01-02 16:00:00, 2017-01-02 17:00:00, 2017-01-02 18:00:00, 2017-01-02 19:00:00, 2017-01-02 20:00:00, 2017-01-02 21:00:00, 2017-01-02 22:00:00, 2017-01-02 23:00:00, 2017-01-03 00:00:00, 2017-01-03 01:00:00, 2017-01-03 02:00:00, 2017-01-03 03:00:00, 2017-01-03 04:00:00, 2017-01-03 05:00:00, 2017-01-03 06:00:00, 2017-01-03 07:00:00, 2017-01-03 08:00:00, 2017-01-03 09:00:00, 2017-01-03 10:00:00, 2017-01-03 11:00:00, 2017-01-03 12:00:00, 2017-01-03 13:00:00, 2017-01-03 14:00:00, 2017-01-03 15:00:00, 2017-01-03 16:00:00, 2017-01-03 17:00:00, 2017-01-03 18:00:00, 2017-01-03 19:00:00, 2017-01-03 20:00:00, 2017-01-03 21:00:00, 2017-01-03 22:00:00, 2017-01-03 23:00:00, 2017-01-04 00:00:00, 2017-01-04 01:00:00, 2017-01-04 02:00:00, 2017-01-04 03:00:00, 2017-01-04 04:00:00, 2017-01-04 05:00:00, 2017-01-04 06:00:00, 2017-01-04 07:00:00, 2017-01-04 08:00:00, 2017-01-04 09:00:00, 2017-01-04 10:00:00, 2017-01-04 11:00:00, 2017-01-04 12:00:00, 2017-01-04 13:00:00, 2017-01-04 14:00:00, 2017-01-04 15:00:00, 2017-01-04 16:00:00, 2017-01-04 17:00:00, 2017-01-04 18:00:00, 2017-01-04 19:00:00, 2017-01-04 20:00:00, 2017-01-04 21:00:00, 2017-01-04 22:00:00, 2017-01-04 23:00:00, 2017-01-05 00:00:00, 2017-01-05 01:00:00, 2017-01-05 02:00:00, 2017-01-05 03:00:00, ...]
#
# [8760 rows x 0 columns]

# %% [markdown]
# In the optimization, we will minimize the annualized system costs.
#
# We will need to annualize the cost of every generator, we build a function to do it.

# %%
def annuity(n,r):
    """ Calculate the annuity factor for an asset with lifetime n years and
    discount rate  r """

    if r > 0:
        return r/(1. - 1./(1.+r)**n)
    else:
        return 1/n

# %% [markdown]
# We include solar PV and onshore wind generators.
#
# The capacity factors representing the availability of those generators for every European country can be downloaded from the following repositories (select 'optimal' for PV and onshore for wind).
#
# https://zenodo.org/record/3253876#.XSiVOEdS8l0
#
# https://zenodo.org/record/2613651#.XSiVOkdS8l0
#
# We include also Open Cycle Gas Turbine (OCGT) generators
#
# The cost assumed for the generators are the same as in Table 1 in the paper https://doi.org/10.1016/j.enconman.2019.111977 (open version:  https://arxiv.org/pdf/1906.06936.pdf)

# %%
# add the different carriers, only gas emits CO2
network.add("Carrier", "gas", co2_emissions=0.19) # in t_CO2/MWh_th
network.add("Carrier", "onshorewind")
network.add("Carrier", "solar")

# add onshore wind generator
df_onshorewind = pd.read_csv('onshore_wind_1979-2017.csv', sep=';', index_col=0)
df_onshorewind.index = pd.to_datetime(df_onshorewind.index)
CF_wind = df_onshorewind[country][[hour.strftime("%Y-%m-%dT%H:%M:%SZ") for hour in network.snapshots]]
#the capacity factor is being extracted with this line above
capital_cost_onshorewind = annuity(30,0.07)*910000*(1+0.033) # in €/MW, this is a formula to calculate annuality in function of years, interest, investment costs and a fix factor
network.add("Generator",
            "onshorewind_NDL",
            bus="electricity bus",
            p_nom_extendable=True,
            carrier="onshorewind",
            #p_nom_max=1000, # maximum capacity can be limited due to environmental constraints
            capital_cost = capital_cost_onshorewind,
            marginal_cost = 0,
            p_max_pu = CF_wind.values, overwrite=True)

network.add("Generator",
            "onshorewind_DEU",
            bus="electricity bus GERMANY",
            p_nom_extendable=True,
            carrier="onshorewind",
            #p_nom_max=1000, # maximum capacity can be limited due to environmental constraints
            capital_cost = capital_cost_onshorewind,
            marginal_cost = 0,
            p_max_pu = CF_wind.values, overwrite=True)

network.add("Generator",
            "onshorewind_BEL",
            bus="electricity bus BELGIUM",
            p_nom_extendable=True,
            carrier="onshorewind",
            #p_nom_max=1000, # maximum capacity can be limited due to environmental constraints
            capital_cost = capital_cost_onshorewind,
            marginal_cost = 0,
            p_max_pu = CF_wind.values, overwrite=True)


# add solar PV generator
df_solar = pd.read_csv('pv_optimal.csv', sep=';', index_col=0)
df_solar.index = pd.to_datetime(df_solar.index)
CF_solar = df_solar[country][[hour.strftime("%Y-%m-%dT%H:%M:%SZ") for hour in network.snapshots]]
capital_cost_solar = annuity(25,0.07)*425000*(1+0.03) # in €/MW
network.add("Generator",
            "solar_NDL",
            bus="electricity bus",
            p_nom_extendable=True,
            carrier="solar",
            #p_nom_max=1000, # maximum capacity can be limited due to environmental constraints
            capital_cost = capital_cost_solar,
            marginal_cost = 0,
            p_max_pu = CF_solar.values, overwrite=True)

network.add("Generator",
            "solar_DEU",
            bus="electricity bus GERMANY",
            p_nom_extendable=True,
            carrier="solar",
            #p_nom_max=1000, # maximum capacity can be limited due to environmental constraints
            capital_cost = capital_cost_solar,
            marginal_cost = 0,
            p_max_pu = CF_solar.values, overwrite=True)

network.add("Generator",
            "solar_BEL",
            bus="electricity bus BELGIUM",
            p_nom_extendable=True,
            carrier="solar",
            #p_nom_max=1000, # maximum capacity can be limited due to environmental constraints
            capital_cost = capital_cost_solar,
            marginal_cost = 0,
            p_max_pu = CF_solar.values, overwrite=True)



# add OCGT (Open Cycle Gas Turbine) generator
capital_cost_OCGT = annuity(25,0.07)*560000*(1+0.033) # in €/MW
fuel_cost = 20.1 # in €/MWh_th
efficiency = 0.39 # MWh_elec/MWh_th
marginal_cost_OCGT = fuel_cost/efficiency # in €/MWh_el
network.add("Generator",
            "OCGT_NDL",
            bus="electricity bus",
            p_nom_extendable=True,
            carrier="gas",
            #p_nom_max=1000,
            capital_cost = capital_cost_OCGT,
            marginal_cost = marginal_cost_OCGT, overwrite=True)

network.add("Generator",
            "OCGT_DEU",
            bus="electricity bus GERMANY",
            p_nom_extendable=True,
            carrier="gas",
            #p_nom_max=1000,
            capital_cost = capital_cost_OCGT,
            marginal_cost = marginal_cost_OCGT, overwrite=True)

network.add("Generator",
            "OCGT_BEL",
            bus="electricity bus BELGIUM",
            p_nom_extendable=True,
            carrier="gas",
            #p_nom_max=1000,
            capital_cost = capital_cost_OCGT,
            marginal_cost = marginal_cost_OCGT, overwrite=True)
# Out:
# Index(['OCGT_BEL'], dtype='object')

# %%
CF_wind = pd.DataFrame()
CF_solar = pd.DataFrame()
for i in range(len(nodes)):
    CF_wind[nodes[i]] = df_onshorewind[nodes[i]][[hour.strftime("%Y-%m-%dT%H:%M:%SZ") for hour in network.snapshots]]
    CF_solar[nodes[i]] = df_solar[nodes[i]][[hour.strftime("%Y-%m-%dT%H:%M:%SZ") for hour in network.snapshots]]

# %%
# add load to the bus
network.add("Load",
            "load NDL",
            bus="electricity bus",
            p_set=df_elec[country].values)

network.add("Load",
            "load GER",
            bus="electricity bus GERMANY",
            p_set=df_elec[country2].values)

network.add("Load",
            "load BEL",
            bus="electricity bus BELGIUM",
            p_set=df_elec[country3].values)


network.add("Load",
            "load BEL",
            bus="electricity bus BELGIUM",
            p_set=df_elec[country3].values)

network.add("Load",
            "load heating GER",
            bus="heating bus GERMANY",
            p_set=df_heat[country2].values)

network.add("Load",
            "load heating BEL",
            bus="heating bus BELGIUM",
            p_set=df_heat[country3].values)

network.add("Load",
            "load h",
            bus="heating bus",
            p_set=df_heat[country].values)
# Out:
# WARNING:pypsa.io:The following loads are already defined and will be skipped (use overwrite=True to overwrite): load BEL
# Index(['load h'], dtype='object')

# %%
network.add(
    "Line",
    'country - country2',
    bus0="electricity bus",
    bus1="electricity bus GERMANY",
    s_nom = 10,
    x = 1,
    r = 1,
    overwrite=True
)
network.add(
    "Line",
    'country - country3',
    bus0="electricity bus",
    bus1="electricity bus BELGIUM",
    s_nom = 10,
    x = 1,
    r = 1,
    overwrite=True
)
network.add(
    "Line",
    'country2 - country3',
    bus0="electricity bus GERMANY",
    bus1="electricity bus BELGIUM",
    s_nom = 10,
    x = 1,
    r = 1,
    overwrite=True
)

network.add("Link",
    "heat_pump",
    bus0="electricity bus",
    bus1="heating bus",
    p_nom=100,
    p_nom_extendable=10,
    efficiency=3.0,
    )

network.add(
        "Link",
        "heat_pump_GER",
        bus0="electricity bus GERMANY",
        bus1="heating bus GERMANY",
        p_nom=100,
        p_nom_extendable=10,
        efficiency=3.0,
    )

network.add(
        "Link",
        "heat_pump_BEL",
        bus0="electricity bus BELGIUM",
        bus1="heating bus BELGIUM",
        p_nom=100,
        p_nom_extendable=10,
        efficiency=3.0,
    )
# Out:
# Index(['heat_pump_BEL'], dtype='object')

# %%
co2_limit=3395000 #tonCO2
#look at the emissions the netherlands emitted in 2015, and put a cap
#network.add("GlobalConstraint",
 #           "co2_limit",
  #          type="primary_energy",
   #         carrier_attribute="co2_emissions",
    #        sense="<=",
        #    constant=co2_limit)

# %%
network.optimize()
# Out:
# WARNING:pypsa.consistency:The following lines have carriers which are not defined:
# Index(['country - country2', 'country - country3', 'country2 - country3'], dtype='object', name='Line')
# WARNING:pypsa.consistency:The following links have carriers which are not defined:
# Index(['heat_pump', 'heat_pump_GER', 'heat_pump_BEL'], dtype='object', name='Link')
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['electricity bus', 'electricity bus GERMANY', 'electricity bus BELGIUM',
#        'heating bus', 'heating bus GERMANY', 'heating bus BELGIUM', 'NLD',
#        'DEU', 'BEL'],
#       dtype='object', name='Bus')
# WARNING:pypsa.consistency:The following buses have no attached components, which can break the lopf: {'NLD', 'DEU', 'BEL'}
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 12/12 [00:02<00:00,  4.25it/s]
# Writing continuous variables.: 100%|██████████| 5/5 [00:00<00:00,  9.22it/s]
# INFO:linopy.io: Writing time: 3.52s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 131412 primals, 324132 duals
# Objective: 6.07e+10
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper, Line-fix-s-lower, Line-fix-s-upper, Link-ext-p-lower, Link-ext-p-upper, Kirchhoff-Voltage-Law were not assigned to the network.
# ('ok', 'optimal')

# %%
print(network.objective/1000000) #in 10^6 €
# Out:
# 60705.40668835192

# %%
network.generators_t.p.to_csv("generators")

# %%
network.links_t.p0
# Out:
# Link                    heat_pump  heat_pump_GER  heat_pump_BEL
# snapshot
# 2017-01-01 00:00:00  10069.589881   60208.648480    9071.509687
# 2017-01-01 01:00:00  10059.494532   59475.942580    8929.604453
# 2017-01-01 02:00:00  10218.933751   59660.756663    9021.080193
# 2017-01-01 03:00:00  10407.065076   60110.750671    9099.585291
# 2017-01-01 04:00:00  10560.841625   60189.576676    9145.622795
# ...                           ...            ...            ...
# 2017-12-31 19:00:00   7856.443109   52352.008749    6289.211601
# 2017-12-31 20:00:00   7984.917751   52920.207725    6254.103927
# 2017-12-31 21:00:00   8085.346879   53126.085425    6260.464301
# 2017-12-31 22:00:00   8149.656880   53282.757686    6299.907506
# 2017-12-31 23:00:00   8176.655667   53418.201549    6314.686693
#
# [8760 rows x 3 columns]

# %%
print(network.objective/network.loads_t.p.sum()) # EUR/MWh
# Out:
# Load
# load NDL            536.030663
# load GER            120.145783
# load BEL            712.329258
# load heating GER     74.268676
# load heating BEL    546.868921
# load h              437.356067
# dtype: float64

# %%
network.buses_t.marginal_price.mean()
# Out:
# Bus
# electricity bus            52.735626
# electricity bus GERMANY    52.797470
# electricity bus BELGIUM    52.810185
# heating bus                17.578542
# heating bus GERMANY        17.599157
# heating bus BELGIUM        17.603395
# NLD                         0.000000
# DEU                         0.000000
# BEL                         0.000000
# dtype: float64

# %%
network.generators_t.p.sum(axis=1).plot(title="Total Electricity Generation")
# Out:
# <Axes: title={'center': 'Total Electricity Generation'}, xlabel='snapshot'>

# %%
network.generators.p_nom_opt # in MW
# Out:
# Generator
# onshorewind_NDL     27376.699266
# onshorewind_DEU    131136.027402
# onshorewind_BEL     20686.774240
# solar_NDL           20390.665367
# solar_DEU           91846.809497
# solar_BEL           14361.910721
# OCGT_NDL            29769.231388
# OCGT_DEU           148003.634663
# OCGT_BEL            23205.595893
# Name: p_nom_opt, dtype: float64

# %%
# Sum flows over each day
daily_flow = network.lines_t.p0.resample('ME').sum()

print(daily_flow)
 #ponerlo por dia o semana, ver los paises que tienen más generacion y deficit y ver cómo debería de fluir la energía dependiendo del overflow o no
# Out:
# Line        country - country2  country - country3  country2 - country3
# snapshot
# 2017-01-31           150.00000          180.000000            30.000000
# 2017-02-28           -80.00000          190.000000           270.000000
# 2017-03-31          -420.00000         -210.000000           210.000000
# 2017-04-30            30.00000          200.000000           170.000000
# 2017-05-31          -330.00000         -280.000000            50.000000
# 2017-06-30            50.00000         -160.000000          -210.000000
# 2017-07-31           100.00000          -88.572185          -188.572185
# 2017-08-31          -370.00000         -140.000000           230.000000
# 2017-09-30           160.00000          345.247012           185.247012
# 2017-10-31           337.85289          -18.468394          -356.321283
# 2017-11-30           -30.00000         -160.000000          -130.000000
# 2017-12-31          -270.00000          309.276599           579.276599

# %%
df = network.lines_t.p0["country - country3"]
df_positive = df[df>0]   # momentos en que COUNTRY exporta
df_negative = df[df<0]   # momentos en que COUNTRY3 exporta
print(df_positive)
print(df_negative)
# Out:
# snapshot
# 2017-01-01 00:00:00    10.0
# 2017-01-01 08:00:00    10.0
# 2017-01-01 10:00:00    10.0
# 2017-01-01 18:00:00    10.0
# 2017-01-01 21:00:00    10.0
#                        ...
# 2017-12-31 15:00:00    10.0
# 2017-12-31 18:00:00    10.0
# 2017-12-31 19:00:00    10.0
# 2017-12-31 21:00:00    10.0
# 2017-12-31 23:00:00    10.0
# Name: country - country3, Length: 2944, dtype: float64
# snapshot
# 2017-01-01 01:00:00   -10.0
# 2017-01-01 02:00:00   -10.0
# 2017-01-01 04:00:00   -10.0
# 2017-01-01 06:00:00   -10.0
# 2017-01-01 09:00:00   -10.0
#                        ...
# 2017-12-31 09:00:00   -10.0
# 2017-12-31 11:00:00   -10.0
# 2017-12-31 12:00:00   -10.0
# 2017-12-31 16:00:00   -10.0
# 2017-12-31 20:00:00   -10.0
# Name: country - country3, Length: 2928, dtype: float64

# %% [markdown]
# Print the generator Capacity factor time series to check that it has been properly added (you should see numbers and not 'NaN')

# %%
network.generators_t.p_max_pu
# Out:
# Generator            onshorewind_BEL  onshorewind_DEU  onshorewind_NDL  \
# snapshot
# 2017-01-01 00:00:00            0.350            0.350            0.350
# 2017-01-01 01:00:00            0.377            0.377            0.377
# 2017-01-01 02:00:00            0.385            0.385            0.385
# 2017-01-01 03:00:00            0.400            0.400            0.400
# 2017-01-01 04:00:00            0.406            0.406            0.406
# ...                              ...              ...              ...
# 2017-12-31 19:00:00            0.468            0.468            0.468
# 2017-12-31 20:00:00            0.595            0.595            0.595
# 2017-12-31 21:00:00            0.684            0.684            0.684
# 2017-12-31 22:00:00            0.762            0.762            0.762
# 2017-12-31 23:00:00            0.827            0.827            0.827
#
# Generator            solar_BEL  solar_DEU  solar_NDL
# snapshot
# 2017-01-01 00:00:00        0.0        0.0        0.0
# 2017-01-01 01:00:00        0.0        0.0        0.0
# 2017-01-01 02:00:00        0.0        0.0        0.0
# 2017-01-01 03:00:00        0.0        0.0        0.0
# 2017-01-01 04:00:00        0.0        0.0        0.0
# ...                        ...        ...        ...
# 2017-12-31 19:00:00        0.0        0.0        0.0
# 2017-12-31 20:00:00        0.0        0.0        0.0
# 2017-12-31 21:00:00        0.0        0.0        0.0
# 2017-12-31 22:00:00        0.0        0.0        0.0
# 2017-12-31 23:00:00        0.0        0.0        0.0
#
# [8760 rows x 6 columns]

# %%
network.links_t.p1["heat_pump"].plot(label="Heat Pump Output (NDL)")
# Out:
# <Axes: xlabel='snapshot'>

# %%
import matplotlib.pyplot as plt # All heat pump outputs (into heating buses)
heat_supply = (
    network.links_t.p1[["heat_pump"]]
    .sum(axis=1)
)

# All heating loads
heat_demand = (
    network.loads_t.p[["load h"]]
    .sum(axis=1)
)

heat_supply.plot(label="Total Heat Supplied")
heat_demand.plot(label="Total Heat Demand", alpha=0.7)
plt.legend()
plt.title("Total Heat Supplied vs Heat Demand")
plt.ylabel("Power [MW]")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Total electricity load across all regions
elec_demand = network.loads_t.p.filter(like="electricity").sum(axis=1)

# Generation by technology
gen_by_carrier = network.generators_t.p.groupby(network.generators.carrier, axis=1).sum()

# Plot
plt.figure(figsize=(14, 5))
gen_by_carrier.plot.area(ax=plt.gca(), linewidth=0)
plt.legend()
plt.title("Electricity Demand with heating met by generators over the year")
plt.ylabel("Power [MW]")
plt.xlabel("Time")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\const\AppData\Local\Temp\ipykernel_28908\3550948795.py:7: FutureWarning:
#
# DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.

# %%
hourly = network.lines_t.p0["country2 - country3"]
cap    = network.lines.loc["country2 - country3","s_nom"]

saturadas = (hourly.abs() >= cap*0.9999).sum()
print(f"saturated hours per year: {saturadas} of {len(hourly)}")
# Out:
# saturated hours per year: 5788 of 8760

# %% [markdown]
# We find the optimal solution using Gurobi as solver.
#
# In this case, we are optimizing the installed capacity and dispatch of every generator to minimize the total system cost.

# %%
print(heat_supply + heat_demand)
# Out:
# snapshot
# 2017-01-01 00:00:00    0.000000e+00
# 2017-01-01 01:00:00    0.000000e+00
# 2017-01-01 02:00:00    0.000000e+00
# 2017-01-01 03:00:00   -3.637979e-12
# 2017-01-01 04:00:00    3.637979e-12
#                            ...
# 2017-12-31 19:00:00    0.000000e+00
# 2017-12-31 20:00:00    0.000000e+00
# 2017-12-31 21:00:00    0.000000e+00
# 2017-12-31 22:00:00    0.000000e+00
# 2017-12-31 23:00:00    0.000000e+00
# Length: 8760, dtype: float64

# %% [markdown]
# The message ('ok' , 'optimal") indicates that the optimizer has found an optimal solution.
#
# The total cost can be read from the network objetive.

# %%
print(network.objective/1000000) #in 10^6 €
# Out:
# 60705.40668835192

# %% [markdown]
# The cost per MWh of electricity produced can also be calculated.

# %%
print(network.objective/network.loads_t.p.sum()) # EUR/MWh
# Out:
# Load
# load NDL            536.030663
# load GER            120.145783
# load BEL            712.329258
# load heating GER     74.268676
# load heating BEL    546.868921
# load h              437.356067
# dtype: float64

# %% [markdown]
# The optimal capacity for every generator can be shown.

# %%
network.generators.p_nom_opt # in MW
# Out:
# Generator
# onshorewind_NDL     27376.699266
# onshorewind_DEU    131136.027402
# onshorewind_BEL     20686.774240
# solar_NDL           20390.665367
# solar_DEU           91846.809497
# solar_BEL           14361.910721
# OCGT_NDL            29769.231388
# OCGT_DEU           148003.634663
# OCGT_BEL            23205.595893
# Name: p_nom_opt, dtype: float64

# %% [markdown]
# We can plot now the dispatch of every generator during the first week of the year and the electricity demand.
# We import the matplotlib package which is very useful to plot results.
#
# We can also plot the electricity mix.

# %%
import matplotlib.pyplot as plt

plt.plot(network.loads_t.p['load'][0:96], color='black', label='demand')
plt.plot(network.generators_t.p['onshorewind'][0:96], color='blue', label='onshore wind')
plt.plot(network.generators_t.p['solar'][0:96], color='orange', label='solar')
plt.plot(network.generators_t.p['OCGT'][0:96], color='brown', label='gas (OCGT)')
plt.legend(fancybox=True, shadow=True, loc='best')
# Out:
# c:\Users\const\anaconda\Lib\site-packages\executing\executing.py:713: DeprecationWarning:
#
# ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#
# c:\Users\const\anaconda\Lib\ast.py:587: DeprecationWarning:
#
# Attribute s is deprecated and will be removed in Python 3.14; use value instead
#
# c:\Users\const\anaconda\Lib\site-packages\executing\executing.py:713: DeprecationWarning:
#
# ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#
# c:\Users\const\anaconda\Lib\ast.py:587: DeprecationWarning:
#
# Attribute s is deprecated and will be removed in Python 3.14; use value instead
#
# c:\Users\const\anaconda\Lib\site-packages\executing\executing.py:713: DeprecationWarning:
#
# ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#
# c:\Users\const\anaconda\Lib\ast.py:587: DeprecationWarning:
#
# Attribute s is deprecated and will be removed in Python 3.14; use value instead
#
# c:\Users\const\anaconda\Lib\site-packages\executing\executing.py:713: DeprecationWarning:
#
# ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#
# c:\Users\const\anaconda\Lib\ast.py:587: DeprecationWarning:
#
# Attribute s is deprecated and will be removed in Python 3.14; use value instead
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\const\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'load'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.plot(network.loads_t.p['load'][0:96], color='black', label='demand')
#       4 plt.plot(network.generators_t.p['onshorewind'][0:96], color='blue', label='onshore wind')
#       5 plt.plot(network.generators_t.p['solar'][0:96], color='orange', label='solar')
#
# File c:\Users\const\anaconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\const\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'load'

# %%
labels = ['onshore wind',
          'solar',
          'gas (OCGT)']
sizes = [network.generators_t.p['onshorewind'].sum(),
         network.generators_t.p['solar'].sum(),
         network.generators_t.p['OCGT'].sum()]

colors=['blue', 'orange', 'brown']

plt.pie(sizes,
        colors=colors,
        labels=labels,
        wedgeprops={'linewidth':0})
plt.axis('equal')

plt.title('Electricity mix', y=1.07)
# Out:
# Text(0.5, 1.07, 'Electricity mix')

# %%
# Define time ranges for summer and winter (assuming hourly data for a full year)
summer_week = pd.date_range("2005-07-01", periods=168, freq="h")
winter_week = pd.date_range("2005-01-01", periods=168, freq="h")

# Extract generation data for summer and winter weeks
dispatch_summer = network.generators_t.p.loc[summer_week]
dispatch_winter = network.generators_t.p.loc[winter_week]

# Plot summer dispatch
plt.figure(figsize=(12, 5))
plt.stackplot(dispatch_summer.index,
              dispatch_summer["onshorewind"],
              dispatch_summer["solar"],
              dispatch_summer["OCGT"],
              labels=["Onshore Wind", "Solar", "Gas (OCGT)"],
              colors=["blue", "orange", "brown"], alpha=0.7)
plt.plot(network.loads_t.p.loc[summer_week, 'load'], color='black', linestyle='-', linewidth=2, label='Demand')
plt.title("Energy Dispatch - Summer Week")
plt.xlabel("Date")
plt.ylabel("Power (MW)")
plt.legend(loc="upper left")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot winter dispatch
plt.figure(figsize=(12, 5))
plt.stackplot(dispatch_winter.index,
              dispatch_winter["onshorewind"],
              dispatch_winter["solar"],
              dispatch_winter["OCGT"],
              labels=["Onshore Wind", "Solar", "Gas (OCGT)"],
              colors=["blue", "orange", "brown"], alpha=0.7)
plt.plot(network.loads_t.p.loc[winter_week, 'load'], color='black', linestyle='-', linewidth=2, label='Demand')
plt.title("Energy Dispatch - Winter Week")
plt.xlabel("Date")
plt.ylabel("Power (MW)")
plt.legend(loc="upper left")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 6
#       3 winter_week = pd.date_range("2005-01-01", periods=168, freq="h")
#       5 # Extract generation data for summer and winter weeks
# ----> 6 dispatch_summer = network.generators_t.p.loc[summer_week]
#       7 dispatch_winter = network.generators_t.p.loc[winter_week]
#       9 # Plot summer dispatch
#
# File ~\PycharmProjects\new-integrated-project\new-integrated-project\.venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\PycharmProjects\new-integrated-project\new-integrated-project\.venv\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~\PycharmProjects\new-integrated-project\new-integrated-project\.venv\Lib\site-packages\pandas\core\indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~\PycharmProjects\new-integrated-project\new-integrated-project\.venv\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~\PycharmProjects\new-integrated-project\new-integrated-project\.venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\PycharmProjects\new-integrated-project\new-integrated-project\.venv\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [DatetimeIndex(['2005-07-01 00:00:00', '2005-07-01 01:00:00',\n               '2005-07-01 02:00:00', '2005-07-01 03:00:00',\n               '2005-07-01 04:00:00', '2005-07-01 05:00:00',\n               '2005-07-01 06:00:00', '2005-07-01 07:00:00',\n               '2005-07-01 08:00:00', '2005-07-01 09:00:00',\n               ...\n               '2005-07-07 14:00:00', '2005-07-07 15:00:00',\n               '2005-07-07 16:00:00', '2005-07-07 17:00:00',\n               '2005-07-07 18:00:00', '2005-07-07 19:00:00',\n               '2005-07-07 20:00:00', '2005-07-07 21:00:00',\n               '2005-07-07 22:00:00', '2005-07-07 23:00:00'],\n              dtype='datetime64[ns]', length=168, freq='h')] are in the [index]"

# %% [markdown]
# We can add a global CO2 constraint and solve again.

# %%
co2_limit=1000000 #tonCO2
#look at the emissions the netherlands emitted in 2015, and put a cap
network.add("GlobalConstraint",
            "co2_limit",
            type="primary_energy",
            carrier_attribute="co2_emissions",
            sense="<=",
            constant=co2_limit)
network.optimize()
# Out:
# WARNING:pypsa.consistency:The following buses have carriers which are not defined:
# Index(['electricity bus'], dtype='object', name='Bus')
# INFO:linopy.model: Solve problem using Highs solver
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 6/6 [00:00<00:00,  7.18it/s]
# Writing continuous variables.: 100%|██████████| 2/2 [00:00<00:00, 13.64it/s]
# INFO:linopy.io: Writing time: 1.05s
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 26283 primals, 61324 duals
# Objective: 2.44e+10
# Solver model: available
# Solver message: optimal
#
# INFO:pypsa.optimization.optimize:The shadow-prices of the constraints Generator-ext-p-lower, Generator-ext-p-upper were not assigned to the network.
# ('ok', 'optimal')

# %%
network.generators.p_nom_opt #in MW
# Out:
# Generator
# onshorewind    273144.976572
# solar           71064.043179
# OCGT            14954.550234
# Name: p_nom_opt, dtype: float64

# %%
plt.plot(network.loads_t.p['load'][0:96], color='black', label='demand')
plt.plot(network.generators_t.p['onshorewind'][0:96], color='blue', label='onshore wind')
plt.plot(network.generators_t.p['solar'][0:96], color='orange', label='solar')
plt.plot(network.generators_t.p['OCGT'][0:96], color='brown', label='gas (OCGT)')
plt.legend(fancybox=True, shadow=True, loc='best')

# %%
labels = ['onshore wind', 'solar', 'gas (OCGT)' ]
sizes = [network.generators_t.p['onshorewind'].sum(),
         network.generators_t.p['solar'].sum(),
         network.generators_t.p['OCGT'].sum()]

colors = ['blue', 'orange', 'brown']

plt.pie(sizes,
        colors=colors,
        labels=labels,
        wedgeprops={'linewidth':0})
plt.axis('equal')

plt.title('Electricity mix', y=1.07)
# Out:
# Text(0.5, 1.07, 'Electricity mix')

# %% [markdown]
# # PROJECT INSTRUCTIONS
#
#
# Based on the previous example, you are asked to carry out the following tasks:
#
# A. Choose a different country/region/city/system and calculate the optimal capacities for renewable and non-renewable generators. You can add as many technologies as you want. Remember to provide a reference for the cost assumptions. Plot the dispatch time series for a week in summer and winter. Plot the annual electricity mix. Use the duration curves or the capacity factor to investigate the contribution of different technologies.
#
# B. Investigate how sensitive the optimum capacity mix is to the global CO2 constraint. E.g., plot the generation mix as a function of the CO2 constraint that you impose. Search for the CO2 emissions in your country (today or in 1990) and refer to the emissions allowance to that historical data.
#
# C. Investigate how sensitive your results are to the interannual variability of solar and wind generation. Plot the average capacity and variability obtained for every generator using different weather years.
#
# D. Add some storage technology/ies and investigate how they behave and what their impact is on the optimal system configuration. Discuss what strategies is your system using to balance the renewable generation at different time scales (intraday, seasonal, etc.)
#
# E. Select one target for decarbonization (i.e., one CO2 allowance limit). What is the CO2 price required to achieve that decarbonization level? Search for information on the existing CO2 tax in your country (if any) and discuss your results.
#
# F. Connect your country with, at least, two neighbouring countries. You can connect them using HVAC lines, HVDC links or gas pipelines. Use a linear representation of power flow or gas flow.
# You can assume that the generation capacities in the neighbouring countries are fixed or optimize the whole system. You can also include fixed interconnection capacities or optimize them with the generators' capacities. Discuss your results.
#
# G. Connect the electricity sector with, at least, another sector( e.g. heating or transport), and co-optimize all the sectors. Discuss your results.
#
# H. Finally, select one topic that is under discussion in your region. Design and implement some experiment to obtain relevant information regarding that topic. E.g.
#
# - What are the consequences if Denmark decides not to install more onshore wind?
#
# - Would it be more expensive if France decides to close its nuclear power plants?
#
# - What will be the main impacts of the Viking link?
#
# - How does gas scarcity impact the optimal system configuration?
#
# **Write a short report (maximum length 10 pages) in groups of 4 students including your main findings.**

# %% [markdown]
# # Hints

# %% [markdown]
# _HINT 1: You can add a link with the following code_
#
# The efficiency will be 1 if you are connecting two countries and different from one if, for example, you are connecting the electricity bus to the heating bus using a heat pump.
# Setting p_min_pu=-1 makes the link reversible.

# %%
network.add("Link",
             'country a - country b',
             bus0="electricity bus country a",
             bus1="electricity bus country b",
             p_nom_extendable=True, # capacity is optimised
             p_min_pu=-1,
             length=600, # length (in km) between country a and country b
             capital_cost=400*600) # capital cost * length
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['country a - country b'], dtype='object')
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['country a - country b'], dtype='object')
# Index(['country a - country b'], dtype='object')

# %% [markdown]
# _HINT 2: You can check the KKT multiplier associated with the constraint with the following code_

# %%
print(network.global_constraints.constant) # CO2 limit (constant in the constraint)
print(network.global_constraints.mu) # CO2 price (Lagrance multiplier in the constraint)
# Out:
# GlobalConstraint
# co2_limit    1000000.0
# Name: constant, dtype: float64
# GlobalConstraint
# co2_limit   -14938.515958
# Name: mu, dtype: float64

# %% [markdown]
# _HINT 3: You can add a H2 store connected to the electricity bus via an electrolyzer and a fuel cell with the following code_

# %%
#Create a new carrier
network.add("Carrier",
              "H2")

#Create a new bus
network.add("Bus",
          "H2",
          carrier = "H2")

#Connect the store to the bus
network.add("Store",
          "H2 Tank",
          bus = "H2",
          e_nom_extendable = True,
          e_cyclic = True,
          capital_cost = annuity(25, 0.07)*57000*(1+0.011))

#Add the link "H2 Electrolysis" that transport energy from the electricity bus (bus0) to the H2 bus (bus1)
#with 80% efficiency
network.add("Link",
          "H2 Electrolysis",
          bus0 = "electricity bus",
          bus1 = "H2",
          p_nom_extendable = True,
          efficiency = 0.8,
          capital_cost = annuity(25, 0.07)*600000*(1+0.05))

#Add the link "H2 Fuel Cell" that transports energy from the H2 bus (bus0) to the electricity bus (bus1)
#with 58% efficiency
network.add("Link",
          "H2 Fuel Cell",
          bus0 = "H2",
          bus1 = "electricity bus",
          p_nom_extendable = True,
          efficiency = 0.58,
          capital_cost = annuity(10, 0.07)*1300000*(1+0.05))
# Out:
# Index(['H2 Fuel Cell'], dtype='object')

# %% [markdown]
# _HINT 4: You can get inspiration for plotting the flows in the network in the following example_
#
# https://pypsa.readthedocs.io/en/latest/examples/flow-plot.html
